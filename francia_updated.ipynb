# %% [markdown]
# # DATOS REALES DE VDG - FRANCIA 2019

# %%
import pandas as pd #Data Frames
import random

# %%
url = 'https://www.interieur.gouv.fr/actualites/communiques/violences-conjugales-enregistrees-par-services-de-securite-en-2019'

# %%
data = {'Crimenes': [3730, 80, 3810, 98],
        'Violaciones' : [3700, 70, 3770, 98],
        'Otros' :[30, 10, 40, 75],
        'Delitos' : [122110, 16390, 138500, 88],
        'Agresiones sexuales' : [620, 10, 630, 98],
        'Violencias intencionales': [90480, 12920, 103400, 88],
        'incluyendo ITT superior a 8 días' :[4060, 380, 4440, 91],
        'incluyendo ITT inferior a 8 días' : [41300, 4930, 46230, 89],
        'incluyendo sin ITT' :[45120, 7610, 52730, 86],
        'Amenazas de muerte / Acoso y otras amenazas' :[14340, 1470, 15810, 91],
        'TOTAL':[16670, 1990, 18660, 89],
       }

df = pd.DataFrame(data)

# %%
pd.DataFrame(data) # df.to_csv('mydata.csv', index=False)
# Out:
#    Crimenes  Violaciones  Otros  Delitos  Agresiones sexuales  \
# 0      3730         3700     30   122110                  620
# 1        80           70     10    16390                   10
# 2      3810         3770     40   138500                  630
# 3        98           98     75       88                   98
#
#    Violencias intencionales  incluyendo ITT superior a 8 días  \
# 0                     90480                              4060
# 1                     12920                               380
# 2                    103400                              4440
# 3                        88                                91
#
#    incluyendo ITT inferior a 8 días  incluyendo sin ITT  \
# 0                             41300               45120
# 1                              4930                7610
# 2                             46230               52730
# 3                                89                  86
#
# ...

# %%
df_transposed = df.transpose()

# %%
df_transposed
# Out:
#                                                   0      1       2   3
# Crimenes                                       3730     80    3810  98
# Violaciones                                    3700     70    3770  98
# Otros                                            30     10      40  75
# Delitos                                      122110  16390  138500  88
# Agresiones sexuales                             620     10     630  98
# Violencias intencionales                      90480  12920  103400  88
# incluyendo ITT superior a 8 días               4060    380    4440  91
# incluyendo ITT inferior a 8 días              41300   4930   46230  89
# incluyendo sin ITT                            45120   7610   52730  86
# Amenazas de muerte / Acoso y otras amenazas   14340   1470   15810  91
# TOTAL                                         16670   1990   18660  89

# %%
df = df_transposed.rename(columns={0: 'mujeres', 1: 'hombres', 2: 'total', 3 : 'porcentaje'})

# %%
df
# Out:
#                                              mujeres  hombres   total  \
# Crimenes                                        3730       80    3810
# Violaciones                                     3700       70    3770
# Otros                                             30       10      40
# Delitos                                       122110    16390  138500
# Agresiones sexuales                              620       10     630
# Violencias intencionales                       90480    12920  103400
# incluyendo ITT superior a 8 días                4060      380    4440
# incluyendo ITT inferior a 8 días               41300     4930   46230
# incluyendo sin ITT                             45120     7610   52730
# Amenazas de muerte / Acoso y otras amenazas    14340     1470   15810
# TOTAL                                          16670     1990   18660
#
#                                              porcentaje
# Crimenes                                             98
# ...

# %%
df.to_csv('/Users/JGR/IRON_HACK/Proyect_4_VDG/francias_updated', index=True)
